# %%
max = 0
min = 999
dicio = {"Miguel":18,"Edwin":21,"Pedro":16, "Marco": 25,"Gerardo":9,"Claudia":21,"Roland":25, "Paco":13}
for k,v in dicio.items():
    print(k,v)
    if (v>max):
        max = v
    if (v<min):
        min = v;
print("Maximo = ", max, "e Mínimo = ", min)
# Out:
# Miguel 18
# Edwin 21
# Pedro 16
# Marco 25
# Gerardo 9
# Claudia 21
# Roland 25
# Paco 13
# Maximo =  25 e Mínimo =  9

# %%
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <command-3466158056386381> in <cell line: 1>()
# ----> 1 input()
#
# /databricks/python/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1154         """
#    1155         if not self._allow_stdin:
# -> 1156             raise StdinNotImplementedError(
#    1157                 "raw_input was called, but this frontend does not support input requests."
#    1158             )
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.
